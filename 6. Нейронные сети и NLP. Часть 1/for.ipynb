# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import torch
from gensim.models import Word2Vec
from tensorflow.keras.layers import TextVectorization, LayerNormalization, Dropout, GlobalAveragePooling1D, Dense, Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import  accuracy_score, f1_score, roc_auc_score, roc_curve, auc
import numpy as np

from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import seaborn as sns
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.initializers import Constant
from sklearn.utils import class_weight

import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet') 



stop_words = set(stopwords.words('english'))

df = pd.read_csv('FakeNewsNet.csv')
df = df[['title', 'news_url', 'source_domain', 'real']]

# Проверка наличия пропущенных значений и удаление строк с пропущенными значениями
print(df.isnull().sum())
df.dropna(inplace=True)

print(df['real'].value_counts())

# Объединяем title, news_url и source_domain в один текстовый столбец
df['text'] = df['title'] + ' ' + df['news_url'] + ' ' + df['source_domain']
df = df[['text', 'real']]

# После объединения столбцов еще раз проверка пропущенных значений
print(df.isnull().sum())

# Количество элементов каждого класса
class_counts = df['real'].value_counts()

# Визуализация графика баланса классов
plt.figure(figsize=(6, 4))
sns.countplot(x='real', data=df, hue='real', palette='Set2', legend=False)
plt.title('Баланс классов')
plt.xlabel('Классы')
plt.ylabel('Количество элементов')
plt.show()

def preprocess_text(text):
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.lower() not in stop_words]
    tokens = [word for word in tokens if word.isalpha()]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

def preprocess_dataframe(dataframe, text_column):
    dataframe[text_column] = dataframe[text_column].apply(preprocess_text)
    return dataframe


# Предварительная обработка текстовых данных
df = preprocess_dataframe(df, 'text')

# Определение гиперпараметров
EMBEDDING_DIM = 256 
HIDDEN_DIM = 128    
OUTPUT_DIM = 1
N_EPOCHS = 20
BATCH = 8

# Разделение текста на предложения
sentences = df['text'].apply(lambda x: x.split())

def create_model(model_type):

  if model_type == 'RNN':
    model_layer = tf.keras.layers.RNN(tf.keras.layers.SimpleRNNCell(HIDDEN_DIM)) 
  elif model_type == 'LSTM':
    model_layer = tf.keras.layers.LSTM(HIDDEN_DIM)  
  elif model_type == 'GRU':
    model_layer = tf.keras.layers.GRU(HIDDEN_DIM)  
  else:
    raise ValueError(f"Unknown model type: {model_type}")

  model = tf.keras.Sequential([
      embedding_layer,
      model_layer,
      tf.keras.layers.Flatten(),
     # Dense(16, activation='relu'),
     # tf.keras.layers.Dropout(0.5),
     # Dense(16, activation='relu'),
      tf.keras.layers.Dropout(0.2),
      LayerNormalization(), 
      Dense(OUTPUT_DIM, activation='sigmoid')
  ])
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model 


# Определяем функцию для обучения модели и выведите на график результаты обучения
def train_and_plot(model_type, train_dataset, test_dataset, BATCH):
    print(model_type)
    model = create_model(model_type)
      
    # Используем early_stop, который прекращает обучение, когда validation loss больше не улучшается
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    
    # Обучение модели
    history = model.fit(X_train, y_train, epochs=N_EPOCHS, validation_split=0.2, batch_size=BATCH, shuffle=True, callbacks=[early_stop])

    results = model.evaluate(test_dataset)
   # print(f'{model_type} - Test Loss: {results[0]}, Test Accuracy: {results[1]}')

    history_dict = history.history
    
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']
    epochs = history.epoch
    
    # Оценка производительности модели
    y_pred = model.predict(X_test)

    # Преобразуем y_pred в бинарные значения (0 или 1)
    y_pred_binary = np.round(y_pred).astype(int) 
    y_pred_binary = np.array(y_pred_binary).flatten()

    accuracy = accuracy_score(y_test, y_pred_binary) 
    f1 = f1_score(y_test, y_pred_binary) 
    roc_auc = roc_auc_score(y_test, y_pred)
    
    print(f'{model_type} - Test Accuracy: {accuracy}, F1-Score: {f1}, AUC-ROC: {roc_auc}')


    return accuracy, f1, roc_auc

# %%
# Гиперпараметры для перебора
embedding_dims = [128, 256]
hidden_dims = [ 128,256]
batch_sizes = [8, 16]

best_accuracy = 0
best_params = {}

for EMBEDDING_DIM in embedding_dims:
    
    for HIDDEN_DIM in hidden_dims:
        
        for BATCH in batch_sizes:
            print(f"EMBEDDING_DIM: {EMBEDDING_DIM}")
            print(f"HIDDEN_DIM: {HIDDEN_DIM}")
            print(f"BATCH: {BATCH}")

            # Обучение модели Word2Vec
            w2v_model = Word2Vec(
                                    sentences=sentences, 
                                    vector_size=EMBEDDING_DIM, 
                                    window=10, 
                                    min_count=1, 
                                    workers=8, 
                                    negative=10,
                                    alpha=0.03,
                                    min_alpha=0.0007,
                                    sample=6e-5,
                                    sg=1, 
                                    hs=1,
                                    seed=42
                                )
 
            w2v_model.build_vocab(sentences)  # Создание словаря модели
            w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=15)  # Обучение модели на предложениях
            w2v_model.save('w2v_model.txt')  # Сохранение обученной модели
            
            # Загрузка обученной модели Word2Vec
            w2v_model = Word2Vec.load('w2v_model.txt')
            
            # Получение вложений слов
            word2vec_vectors = w2v_model.wv
            
            # Преобразование вложений слов в тензор TensorFlow
            pre_trained_emb = tf.convert_to_tensor(word2vec_vectors.vectors, dtype=tf.float32)
            
            # Добавление строки заполнения
            padding_row = tf.zeros([1, EMBEDDING_DIM], dtype=tf.float32) 
            pre_trained_emb = tf.concat([pre_trained_emb, padding_row], axis=0)
            
            INPUT_DIM = len(word2vec_vectors.key_to_index) + 1
            
            # Определение максимального размера словаря
            max_size = len(w2v_model.wv.key_to_index)
            
            # Создает словарь из num_words наиболее часто встречающихся слов в тексте.
            tokenizer = Tokenizer(num_words=max_size)  # Используем max_size, чтобы сохранить все слова из Word2Vec
            tokenizer.fit_on_texts(df['text'])
            
            # Преобразует текст в последовательности целых чисел (индексы слов в словаре).
            tokenized_text = tokenizer.texts_to_sequences(df['text'])
            
            # Выравнивание последовательностей по длине (паддинг), для передачи в модель
            maxlen = max(len(x) for x in tokenized_text)
            padded_text = pad_sequences(tokenized_text, maxlen=maxlen)
            
            # Создание Embedding-слоя
            embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, w2v_model.vector_size))  # Размер соответствует словарю Tokenizer
            
            # Итерация по словарю "слово: индекс"
            for word, i in tokenizer.word_index.items():
                # Если индекс превышает кол-во слов в словаре, то скипаем
                if i > tokenizer.num_words:
                    continue
                # Проверяем, существует ли слово в словаре w2v_model.wv
                if word in w2v_model.wv:
                    # Получаем вектор соответствущий слову в модели word2vec
                    embedding_vector = w2v_model.wv[word]
                    # Если слово найдено в словаре токенизатора, то в embedding_matrix проставляем вектор соответствующий слову
                    embedding_matrix[i] = embedding_vector
                else:
                    # Если слово не найдено, то можно использовать нулевой вектор
                    embedding_matrix[i] = np.zeros(w2v_model.vector_size) 
            
            
            # Embedding слой
            embedding_layer = Embedding(
                # Размер словаря
                input_dim = len(tokenizer.word_index) + 1,  # Используем размер словаря Tokenizer
                # Размер вектора вложений
                output_dim = w2v_model.vector_size,
                # Установка весов слоя
                embeddings_initializer = Constant(embedding_matrix),
                # Длина входных последовательностей
                input_length = maxlen,
                # Предотвратит обновление весов во время обучения
                trainable = False
                )
            
            # Разделение данных на обучающую и тестовую выборки
            X_train, X_test, y_train, y_test = train_test_split(padded_text, df['real'], test_size=0.20, random_state=42) 
            
            train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH)
            test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH)
            
            accuracy, f1, roc_auc = train_and_plot('RNN', train_dataset, test_dataset, BATCH)
            
            # Сохраняем наилучшую модель
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_f1 = f1
                best_roc_auc = roc_auc
                best_params = {
                    'embedding_dim': EMBEDDING_DIM,
                    'hidden_dim': HIDDEN_DIM,
                    'batch_size': BATCH,

                        }


print(f"Лучшая точность: {best_accuracy}")
print(f"Лучшая f1: {best_f1}")
print(f"Лучшая ROC AUC: {best_roc_auc}")
print(f"Лучшие параметры: {best_params}")
# Out:
# EMBEDDING_DIM: 128
# HIDDEN_DIM: 128
# BATCH: 8
# RNN
# Epoch 1/20
# 1830/1830 [==============================] - 19s 10ms/step - loss: 0.4400 - accuracy: 0.8155 - val_loss: 0.4049 - val_accuracy: 0.8412
# Epoch 2/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.4089 - accuracy: 0.8330 - val_loss: 0.4154 - val_accuracy: 0.8131
# Epoch 3/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3891 - accuracy: 0.8395 - val_loss: 0.3874 - val_accuracy: 0.8407
# Epoch 4/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3927 - accuracy: 0.8365 - val_loss: 0.4024 - val_accuracy: 0.8278
# Epoch 5/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3715 - accuracy: 0.8473 - val_loss: 0.3833 - val_accuracy: 0.8434
# Epoch 6/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3625 - accuracy: 0.8517 - val_loss: 0.3910 - val_accuracy: 0.8450
# Epoch 7/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3736 - accuracy: 0.8458 - val_loss: 0.3818 - val_accuracy: 0.8415
# Epoch 8/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3747 - accuracy: 0.8453 - val_loss: 0.3897 - val_accuracy: 0.8420
# Epoch 9/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3815 - accuracy: 0.8443 - val_loss: 0.3840 - val_accuracy: 0.8426
# Epoch 10/20
# 1830/1830 [==============================] - 18s 10ms/step - loss: 0.3773 - accuracy: 0.8413 - val_loss: 0.3857 - val_accuracy: 0.8316
# 572/572 [==============================] - 3s 4ms/step - loss: 0.3783 - accuracy: 0.8374
# 143/143 [==============================] - 1s 4ms/step
# RNN - Test Accuracy: 0.8373414954088325, F1-Score: 0.9001878186208747, AUC-ROC: 0.8558850269158376
# EMBEDDING_DIM: 128
# HIDDEN_DIM: 128
# BATCH: 16
# RNN
# Epoch 1/20
# 915/915 [==============================] - 11s 11ms/step - loss: 0.4345 - accuracy: 0.8178 - val_loss: 0.3777 - val_accuracy: 0.8431
# Epoch 2/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.4017 - accuracy: 0.8374 - val_loss: 0.3870 - val_accuracy: 0.8330
# Epoch 3/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3832 - accuracy: 0.8421 - val_loss: 0.3654 - val_accuracy: 0.8475
# Epoch 4/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3679 - accuracy: 0.8514 - val_loss: 0.3671 - val_accuracy: 0.8513
# Epoch 5/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3637 - accuracy: 0.8545 - val_loss: 0.3877 - val_accuracy: 0.8480
# Epoch 6/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3631 - accuracy: 0.8522 - val_loss: 0.3653 - val_accuracy: 0.8497
# Epoch 7/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3762 - accuracy: 0.8466 - val_loss: 0.3770 - val_accuracy: 0.8431
# Epoch 8/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3550 - accuracy: 0.8548 - val_loss: 0.3706 - val_accuracy: 0.8442
# Epoch 9/20
# 915/915 [==============================] - 9s 10ms/step - loss: 0.3419 - accuracy: 0.8587 - val_loss: 0.4046 - val_accuracy: 0.8508
# 286/286 [==============================] - 2s 5ms/step - loss: 0.3691 - accuracy: 0.8471
# 143/143 [==============================] - 1s 4ms/step
# RNN - Test Accuracy: 0.8471797114123306, F1-Score: 0.904521240267723, AUC-ROC: 0.8615687231053586
# EMBEDDING_DIM: 128
# HIDDEN_DIM: 256
# BATCH: 8
# RNN
# Epoch 1/20
# 1830/1830 [==============================] - 33s 17ms/step - loss: 0.4974 - accuracy: 0.7952 - val_loss: 0.4102 - val_accuracy: 0.8292
# Epoch 2/20
# 1830/1830 [==============================] - 31s 17ms/step - loss: 0.4352 - accuracy: 0.8221 - val_loss: 0.3891 - val_accuracy: 0.8366
# Epoch 3/20
# 1830/1830 [==============================] - 31s 17ms/step - loss: 0.4068 - accuracy: 0.8352 - val_loss: 0.3965 - val_accuracy: 0.8330
# Epoch 4/20
# 1830/1830 [==============================] - 31s 17ms/step - loss: 0.4007 - accuracy: 0.8420 - val_loss: 0.4034 - val_accuracy: 0.8319
# Epoch 5/20
# 1830/1830 [==============================] - 31s 17ms/step - loss: 0.3971 - accuracy: 0.8393 - val_loss: 0.4360 - val_accuracy: 0.8306
# 572/572 [==============================] - 4s 7ms/step - loss: 0.3846 - accuracy: 0.8395
# 143/143 [==============================] - 2s 11ms/step
# RNN - Test Accuracy: 0.8395277656318321, F1-Score: 0.9015557939914163, AUC-ROC: 0.8503197682381377
# EMBEDDING_DIM: 128
# HIDDEN_DIM: 256
# BATCH: 16
# RNN
# Epoch 1/20
# 915/915 [==============================] - 22s 22ms/step - loss: 0.4670 - accuracy: 0.8048 - val_loss: 0.4037 - val_accuracy: 0.8213
# Epoch 2/20
# 915/915 [==============================] - 20s 21ms/step - loss: 0.4147 - accuracy: 0.8279 - val_loss: 0.3963 - val_accuracy: 0.8333
# Epoch 3/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.4282 - accuracy: 0.8268 - val_loss: 0.3956 - val_accuracy: 0.8360
# Epoch 4/20
# 915/915 [==============================] - 17s 18ms/step - loss: 0.4211 - accuracy: 0.8244 - val_loss: 0.3948 - val_accuracy: 0.8360
# Epoch 5/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3898 - accuracy: 0.8395 - val_loss: 0.3879 - val_accuracy: 0.8423
# Epoch 6/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3829 - accuracy: 0.8420 - val_loss: 0.3738 - val_accuracy: 0.8445
# Epoch 7/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3814 - accuracy: 0.8440 - val_loss: 0.3743 - val_accuracy: 0.8448
# Epoch 8/20
# 915/915 [==============================] - 16s 17ms/step - loss: 0.3714 - accuracy: 0.8482 - val_loss: 0.3736 - val_accuracy: 0.8459
# Epoch 9/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3803 - accuracy: 0.8426 - val_loss: 0.3861 - val_accuracy: 0.8379
# Epoch 10/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3801 - accuracy: 0.8423 - val_loss: 0.3755 - val_accuracy: 0.8456
# Epoch 11/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3708 - accuracy: 0.8486 - val_loss: 0.3684 - val_accuracy: 0.8448
# Epoch 12/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3676 - accuracy: 0.8477 - val_loss: 0.3635 - val_accuracy: 0.8478
# Epoch 13/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3639 - accuracy: 0.8511 - val_loss: 0.3808 - val_accuracy: 0.8521
# Epoch 14/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3662 - accuracy: 0.8475 - val_loss: 0.3671 - val_accuracy: 0.8437
# Epoch 15/20
# 915/915 [==============================] - 16s 18ms/step - loss: 0.3786 - accuracy: 0.8403 - val_loss: 0.3811 - val_accuracy: 0.8297
# 286/286 [==============================] - 4s 10ms/step - loss: 0.3613 - accuracy: 0.8515
# 143/143 [==============================] - 2s 9ms/step
# RNN - Test Accuracy: 0.8515522518583297, F1-Score: 0.907681849082257, AUC-ROC: 0.8676477762313655
# EMBEDDING_DIM: 256
# HIDDEN_DIM: 128
# BATCH: 8
# RNN
# Epoch 1/20
# 1830/1830 [==============================] - 22s 11ms/step - loss: 0.4236 - accuracy: 0.8247 - val_loss: 0.3778 - val_accuracy: 0.8388
# Epoch 2/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3835 - accuracy: 0.8417 - val_loss: 0.3666 - val_accuracy: 0.8480
# Epoch 3/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3707 - accuracy: 0.8507 - val_loss: 0.3640 - val_accuracy: 0.8483
# Epoch 4/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3744 - accuracy: 0.8460 - val_loss: 0.3624 - val_accuracy: 0.8459
# Epoch 5/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3572 - accuracy: 0.8538 - val_loss: 0.4027 - val_accuracy: 0.8415
# Epoch 6/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3530 - accuracy: 0.8562 - val_loss: 0.3514 - val_accuracy: 0.8560
# Epoch 7/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3378 - accuracy: 0.8596 - val_loss: 0.3467 - val_accuracy: 0.8573
# Epoch 8/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3345 - accuracy: 0.8594 - val_loss: 0.3454 - val_accuracy: 0.8568
# Epoch 9/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3253 - accuracy: 0.8641 - val_loss: 0.3605 - val_accuracy: 0.8554
# Epoch 10/20
# 1830/1830 [==============================] - 20s 11ms/step - loss: 0.3191 - accuracy: 0.8700 - val_loss: 0.3616 - val_accuracy: 0.8527
# Epoch 11/20
# 1830/1830 [==============================] - 21s 11ms/step - loss: 0.3289 - accuracy: 0.8644 - val_loss: 0.3538 - val_accuracy: 0.8562
# 572/572 [==============================] - 3s 5ms/step - loss: 0.3423 - accuracy: 0.8599
# 143/143 [==============================] - 2s 10ms/step
# RNN - Test Accuracy: 0.859860078705728, F1-Score: 0.9123957906245729, AUC-ROC: 0.8800723668849761
# EMBEDDING_DIM: 256
# HIDDEN_DIM: 128
# BATCH: 16
# RNN
# Epoch 1/20
# 915/915 [==============================] - 13s 13ms/step - loss: 0.4216 - accuracy: 0.8279 - val_loss: 0.3789 - val_accuracy: 0.8363
# Epoch 2/20
# 915/915 [==============================] - 12s 13ms/step - loss: 0.3666 - accuracy: 0.8514 - val_loss: 0.4208 - val_accuracy: 0.8412
# Epoch 3/20
# 915/915 [==============================] - 11s 12ms/step - loss: 0.3547 - accuracy: 0.8545 - val_loss: 0.3794 - val_accuracy: 0.8502
# Epoch 4/20
# 915/915 [==============================] - 11s 12ms/step - loss: 0.3474 - accuracy: 0.8569 - val_loss: 0.3695 - val_accuracy: 0.8571
# Epoch 5/20
# 915/915 [==============================] - 11s 13ms/step - loss: 0.3310 - accuracy: 0.8655 - val_loss: 0.3549 - val_accuracy: 0.8549
# Epoch 6/20
# 915/915 [==============================] - 11s 12ms/step - loss: 0.3194 - accuracy: 0.8681 - val_loss: 0.3497 - val_accuracy: 0.8598
# Epoch 7/20
# 915/915 [==============================] - 11s 13ms/step - loss: 0.3208 - accuracy: 0.8684 - val_loss: 0.3827 - val_accuracy: 0.8327
# Epoch 8/20
# 915/915 [==============================] - 11s 12ms/step - loss: 0.3254 - accuracy: 0.8665 - val_loss: 0.3595 - val_accuracy: 0.8587
# Epoch 9/20
# 915/915 [==============================] - 11s 12ms/step - loss: 0.3072 - accuracy: 0.8739 - val_loss: 0.3639 - val_accuracy: 0.8598
# 286/286 [==============================] - 2s 5ms/step - loss: 0.3468 - accuracy: 0.8587
# 143/143 [==============================] - 2s 11ms/step
# RNN - Test Accuracy: 0.8587669435942282, F1-Score: 0.9107241569928137, AUC-ROC: 0.8774923074314323
# EMBEDDING_DIM: 256
# HIDDEN_DIM: 256
# BATCH: 8
# RNN
# Epoch 1/20
# 1830/1830 [==============================] - 33s 17ms/step - loss: 0.4632 - accuracy: 0.8098 - val_loss: 0.5018 - val_accuracy: 0.7688
# Epoch 2/20
# 1830/1830 [==============================] - 31s 17ms/step - loss: 0.4012 - accuracy: 0.8355 - val_loss: 0.3856 - val_accuracy: 0.8464
# Epoch 3/20
# 1830/1830 [==============================] - 32s 17ms/step - loss: 0.3943 - accuracy: 0.8388 - val_loss: 0.4023 - val_accuracy: 0.8390
# Epoch 4/20
# 1830/1830 [==============================] - 32s 17ms/step - loss: 0.3868 - accuracy: 0.8449 - val_loss: 0.3778 - val_accuracy: 0.8459
# Epoch 5/20
# 1830/1830 [==============================] - 32s 17ms/step - loss: 0.4028 - accuracy: 0.8381 - val_loss: 0.4166 - val_accuracy: 0.8303
# Epoch 6/20
# 1830/1830 [==============================] - 31s 17ms/step - loss: 0.4069 - accuracy: 0.8362 - val_loss: 0.3943 - val_accuracy: 0.8398
# Epoch 7/20
# 1830/1830 [==============================] - 32s 17ms/step - loss: 0.3967 - accuracy: 0.8419 - val_loss: 0.4320 - val_accuracy: 0.8286
# 572/572 [==============================] - 5s 7ms/step - loss: 0.3701 - accuracy: 0.8501
# 143/143 [==============================] - 2s 13ms/step
# RNN - Test Accuracy: 0.85002186270223, F1-Score: 0.9058726673984633, AUC-ROC: 0.8633841562436004
# EMBEDDING_DIM: 256
# HIDDEN_DIM: 256
# BATCH: 16
# RNN
# Epoch 1/20
# 915/915 [==============================] - 29s 31ms/step - loss: 0.4267 - accuracy: 0.8235 - val_loss: 0.3813 - val_accuracy: 0.8434
# Epoch 2/20
# 915/915 [==============================] - 32s 35ms/step - loss: 0.3806 - accuracy: 0.8414 - val_loss: 0.4263 - val_accuracy: 0.8043
# Epoch 3/20
# 915/915 [==============================] - 33s 36ms/step - loss: 0.3822 - accuracy: 0.8420 - val_loss: 0.3948 - val_accuracy: 0.8371
# Epoch 4/20
# 915/915 [==============================] - 33s 36ms/step - loss: 0.3622 - accuracy: 0.8510 - val_loss: 0.3541 - val_accuracy: 0.8532
# Epoch 5/20
# 915/915 [==============================] - 33s 36ms/step - loss: 0.3612 - accuracy: 0.8508 - val_loss: 0.3559 - val_accuracy: 0.8502
# Epoch 6/20
# 915/915 [==============================] - 33s 36ms/step - loss: 0.3625 - accuracy: 0.8492 - val_loss: 0.3791 - val_accuracy: 0.8404
# Epoch 7/20
# 915/915 [==============================] - 34s 37ms/step - loss: 0.3524 - accuracy: 0.8543 - val_loss: 0.3596 - val_accuracy: 0.8489
# 286/286 [==============================] - 9s 29ms/step - loss: 0.3491 - accuracy: 0.8576
# 143/143 [==============================] - 2s 16ms/step
# RNN - Test Accuracy: 0.8576738084827285, F1-Score: 0.9096962130669995, AUC-ROC: 0.8785864196001039
# Лучшая точность: 0.859860078705728
# Лучшая f1: 0.9123957906245729
# Лучшая ROC AUC: 0.8800723668849761
# Лучшие параметры: {'embedding_dim': 256, 'hidden_dim': 128, 'batch_size': 8}
